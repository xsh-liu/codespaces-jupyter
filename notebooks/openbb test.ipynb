# %%
from openbb_terminal.sdk import openbb

# %%
openbb.economy.events()
# Out:
#    Time (GMT)         Country                                       Event  \
# 0       02:45          France                  French Consumer Confidence
# 1       03:00           Spain                                 Spanish GDP
# 2       03:00           Spain                                 Spanish GDP
# 3       04:00           Italy                    Italian Industrial Sales
# 4       04:00           Italy                    Italian Industrial Sales
# 5       04:00       Euro Zone                             M3 Money Supply
# 6       04:00       Euro Zone         Loans to Non Financial Corporations
# 7       04:00       Euro Zone                        Private Sector Loans
# 8       05:30       Euro Zone                ECB President Lagarde Speaks
# 9       06:30           India                            Bank Loan Growth
# 10      06:30           India                              Deposit Growth
# 11      07:30          Brazil                                Bank lending
# ...
